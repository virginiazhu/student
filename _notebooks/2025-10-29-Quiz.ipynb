# %% [markdown]
# ---
# title: Grade Predictor
# comments: true
# layout: post
# permalink: /quiz
# description: Quiz
# author: Arya, Tarun, Akshaj, Jonah
# ---

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Python Button Challenge</title>
    <style>
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }
        
        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            min-height: 100vh;
            padding: 20px;
        }
        
        .container {
            max-width: 1400px;
            margin: 0 auto;
            background: white;
            border-radius: 15px;
            box-shadow: 0 20px 60px rgba(0,0,0,0.3);
            overflow: hidden;
        }
        
        .header {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            padding: 30px;
            text-align: center;
        }
        
        .header h1 {
            font-size: 2.5em;
            margin-bottom: 10px;
        }
        
        .content {
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 0;
            min-height: 600px;
        }
        
        .left-panel {
            padding: 40px;
            background: #f8f9fa;
            border-right: 3px solid #e9ecef;
            overflow-y: auto;
        }
        
        .right-panel {
            padding: 40px;
            display: flex;
            flex-direction: column;
            background: white;
        }
        
        .code-section h2 {
            color: #667eea;
            margin-bottom: 20px;
            font-size: 1.8em;
        }
        
        .code-area {
            background: white;
            padding: 25px;
            border-radius: 8px;
            font-family: 'Courier New', monospace;
            font-size: 1.05em;
            border: 2px solid #dee2e6;
        }
        
        .code-line {
            margin-bottom: 12px;
            line-height: 1.8;
        }
        
        .indent-1 {
            margin-left: 20px;
        }
        
        .indent-2 {
            margin-left: 100px;
        }
        
        .keyword {
            color: #c792ea;
            font-weight: bold;
        }
        
        .function {
            color: #82aaff;
        }
        
        .number {
            color: #f78c6c;
        }
        
        .fill-blank {
            display: inline-block;
            min-width: 150px;
            padding: 8px 12px;
            border: 2px solid #667eea;
            border-radius: 4px;
            background: white;
            font-family: 'Courier New', monospace;
            font-size: 1em;
            transition: all 0.3s;
        }
        
        .fill-blank:focus {
            outline: none;
            border-color: #764ba2;
            box-shadow: 0 0 0 3px rgba(102, 126, 234, 0.1);
        }
        
        .small-blank {
            min-width: 100px;
        }
        
        .run-button {
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white;
            border: none;
            padding: 15px 40px;
            font-size: 1.2em;
            border-radius: 8px;
            cursor: pointer;
            margin-top: 20px;
            transition: transform 0.2s, box-shadow 0.2s;
            font-weight: bold;
        }
        
        .run-button:hover {
            transform: translateY(-2px);
            box-shadow: 0 5px 15px rgba(102, 126, 234, 0.4);
        }
        
        .run-button:active {
            transform: translateY(0);
        }
        
        .output-area {
            flex: 1;
            background: #f8f9fa;
            border: 2px solid #e9ecef;
            border-radius: 8px;
            padding: 25px;
            margin-top: 20px;
            min-height: 250px;
        }
        
        .output-area h3 {
            color: #667eea;
            margin-bottom: 20px;
            font-size: 1.5em;
        }
        
        .generated-button {
            padding: 12px 24px;
            font-size: 1em;
            border-radius: 5px;
            border: none;
            cursor: pointer;
            margin: 10px 5px;
            transition: all 0.3s;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2);
        }
        
        .generated-button:hover {
            transform: scale(1.05);
            box-shadow: 0 4px 10px rgba(0,0,0,0.3);
        }
        
        .feedback {
            padding: 15px;
            border-radius: 5px;
            margin-top: 15px;
            font-weight: bold;
        }
        
        .success {
            background: #d4edda;
            color: #155724;
            border: 1px solid #c3e6cb;
        }
        
        .error {
            background: #f8d7da;
            color: #721c24;
            border: 1px solid #f5c6cb;
        }

        @media (max-width: 968px) {
            .content {
                grid-template-columns: 1fr;
            }
            
            .left-panel {
                border-right: none;
                border-bottom: 3px solid #e9ecef;
            }
        }
    </style>
</head>
<body>
    <div class="container">
        <div class="header">
            <h1>🖱️ Python Button Challenge</h1>
        </div>
        
        <div class="content">
            <div class="left-panel">
                <div class="code-section">
                    <h2>✏️ Fill in the Code:</h2>
                    <div class="code-area">
                        <div class="code-line">
                            <span class="keyword">import</span> tkinter <span class="keyword">as</span> tk
                        </div>
                        
                        <div class="code-line" style="margin-top: 15px;">
                            <span class="keyword">def</span> <span class="function">show_message</span>():
                        </div>
                        <div class="code-line indent-1">
                            <span class="function">print</span>(<input type="text" class="fill-blank" id="blank1" placeholder="message text">)
                        </div>
                        
                        <div class="code-line" style="margin-top: 15px;">
                            window = tk.<span class="function">Tk</span>()
                        </div>
                        
                        <div class="code-line" style="margin-top: 10px;">
                            button = tk.<span class="function">Button</span>(window,
                        </div>
                        <div class="code-line indent-2">
                            text=<input type="text" class="fill-blank" id="blank2" placeholder="button text">,
                        </div>
                        <div class="code-line indent-2">
                            command=<input type="text" class="fill-blank" id="blank3" placeholder="function name">,
                        </div>
                        <div class="code-line indent-2">
                            bg=<input type="text" class="fill-blank small-blank" id="blank4" placeholder="color">,
                        </div>
                        <div class="code-line indent-2">
                            fg=<input type="text" class="fill-blank small-blank" id="blank5" placeholder="color">)
                        </div>
                        
                        <div class="code-line" style="margin-top: 10px;">
                            button.<span class="function">pack</span>(pady=<span class="number">20</span>)
                        </div>
                        
                        <div class="code-line">
                            window.<span class="function">mainloop</span>()
                        </div>
                    </div>
                </div>
            </div>
            
            <div class="right-panel">
                <h2 style="color: #667eea; margin-bottom: 20px;">▶️ Run Your Code</h2>
                <button class="run-button" onclick="runCode()">🚀 Run Code</button>
                
                <div class="output-area">
                    <h3>Output:</h3>
                    <div id="output"></div>
                </div>
            </div>
        </div>
    </div>

    <script>
        function runCode() {
            const blank1 = document.getElementById('blank1').value.trim();
            const blank2 = document.getElementById('blank2').value.trim();
            const blank3 = document.getElementById('blank3').value.trim();
            const blank4 = document.getElementById('blank4').value.trim();
            const blank5 = document.getElementById('blank5').value.trim();
            
            const output = document.getElementById('output');
            output.innerHTML = '';
            
            if (!blank1 || !blank2 || !blank3 || !blank4 || !blank5) {
                output.innerHTML = '<div class="feedback error">❌ Please fill in all the blanks!</div>';
                return;
            }
            
            if (blank3 !== 'show_message') {
                output.innerHTML = '<div class="feedback error">❌ The command should be the function name: show_message (without parentheses!)</div>';
                return;
            }
            
            output.innerHTML = `
                <div class="feedback success">✅ Great job! Your code works!</div>
                <div style="margin-top: 20px;">
                    <p style="margin-bottom: 10px; font-weight: bold; font-size: 1.1em;">Your Button:</p>
                    <button class="generated-button" 
                            style="background-color: ${blank4}; color: ${blank5};"
                            onclick="showMessage('${blank1}')">${blank2}</button>
                    <p style="margin-top: 10px; color: #6c757d; font-size: 0.9em;">👆 Click the button to test it!</p>
                </div>
            `;
        }
        
        function showMessage(msg) {
            const output = document.getElementById('output');
            const messageDiv = document.createElement('div');
            messageDiv.style.cssText = 'margin-top: 15px; padding: 15px; background: #d1ecf1; border-left: 4px solid #0c5460; color: #0c5460; border-radius: 4px; font-weight: bold;';
            messageDiv.innerHTML = `📢 Console Output: ${msg}`;
            output.appendChild(messageDiv);
        }
        
        document.addEventListener('keypress', function(e) {
            if (e.key === 'Enter') {
                runCode();
            }
        });
    </script>
</body>
</html>
