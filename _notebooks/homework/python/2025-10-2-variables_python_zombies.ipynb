# %% [raw]
# ---
# layout: post
# title: Variables & Assignments
# description: This page will provide homework for the variables and assigmnets lesson.
# permalink: /python/variables/zombies/hw
# breadcrumb: True
# Author: Ethan Patel, Tanay Paranjpe, Neil Manjrekar
# ---

# %% [markdown]
# ## Variables & Assignment Homework
# ---
# Description:
# - In this homework hack, you will practice creating and using variables. You’ll define variables to store your name and age, reassign values, and answer interactive questions to test your understanding. This activity will help you master the basics of variables and how they work in programming.

# %% [markdown]
# # 🏠 Variables Quest Homework
#
# **Objective:** Practice creating, manipulating, and combining strings in Python.
#
# ---
#
# ## Instructions
#
# Complete each challenge by **filling in the missing code**. Use the examples as a guide, but make sure to write your own values or logic.

# %% [markdown]
# ## Challenge 1: Creating a Life Profile with Variables

# %%
# Part 1
## Personal info
my_name = "Virginia"           # Fill in your name
my_age = "15"           # Fill in your age
my_city = "San Diego"           # Fill in the city where you live

# Part 2
## Preferences
favorite_color = "Red"    # Your favorite color
favorite_food = "Ramen"     # Your favorite food
favorite_movie = "Interstellar"   # Your favorite movie
favorite_song = "Stars Align"    # Your favorite song

# Part 3
# Reassign some variables
favorite_food = "Sushi"
my_city = "Los Angeles"
has_pet = "False"
# Part 5: Print Your Life Profile

print("Name:", my_name)
print("Age:", my_age)
print("City:", my_city)
print("Favorite color:", favorite_color)
print("Favorite food:", favorite_food)
print("Favorite movie:", favorite_movie)
print("Favorite song:", favorite_song)
print("Has pet?", has_pet)
# Out:
# Name: Virginia
# Age: 15
# City: Los Angeles
# Favorite color: Red
# Favorite food: Sushi
# Favorite movie: Interstellar
# Favorite song: Stars Align
# Has pet? False

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Creative Challenge
#
# Your task: Create a “story” or “profile” using **ONLY variables and assignments**.
#
#
# ### Instructions:
#
# 1. **Create at least 8 variables** to describe a character or yourself.
#    Examples:
#    `name`, `age`, `favorite_food`, `hobby`, `number_of_pets`, `mood`, `favorite_color`, `dream_job`
#
# 2. **Assign initial values** to all variables.
#
# 3. **Reassign at least 4 of the variables** to new values to simulate changes over time or “events” in the story.
#
# 4. Use **print statements** to write a story or profile that is **at least 5 sentences long**.
#    Each sentence should include at least one variable.
#    Example:
#    > "Tanay ('age' 17) loves pizza and plays tennis ('hobby') every weekend. Today, Tanay is happy because he ate his ('favoirite_food')."
#
# 5. Optional: Add **extra variables** to make your story longer and more creative.
#    You can also create “day 2”, “day 3”, etc., by reassigning variables and printing new sentences.
#
# ### Goal:
#
# - Show creativity while practicing:
#   - Variable creation
#   - Variable reassignment
#   - Using variables in print statements
#   - Experiment with assigment and reassigment to update variables

# %%
name = "Virginia"
age = 15
favorite_food = "dumplings"
hobby = "playing piano"
number_of_pets = 1
mood = "curious"
favorite_color = "navy blue"
dream_job = "software engineer"

print(name, "is", age, "years old and her favorite food is", favorite_food + ".")
print("In her free time, she enjoys", hobby, "and taking care of her", number_of_pets, "pet.")
print("Today, she feels", mood, "and is dressed in her favorite color,", favorite_color + ".")
print("In the future,", name, "hopes to become a", dream_job + ".")

# time passes...
age = 16
favorite_food = "ramen"
hobby = "reading"
mood = "sleepy"
number_of_pets = 2

print("\nA year later...")
print(name, "is now", age, "and has discovered a new love for", favorite_food + ".")
print("Her hobby has shifted from", hobby, "to something different she enjoys now.")
print("After a long day, she feels", mood, "but still takes care of her", number_of_pets, "pets.")
print("But one thing hasn’t changed:", name, "still dreams of becoming a", dream_job + ".")
# Out:
# Virginia is 15 years old and her favorite food is dumplings.
# In her free time, she enjoys playing piano and taking care of her 1 pet.
# Today, she feels curious and is dressed in her favorite color, navy blue.
# In the future, Virginia hopes to become a software engineer.
#
# A year later...
# Virginia is now 16 and has discovered a new love for ramen.
# Her hobby has shifted from reading to something different she enjoys now.
# After a long day, she feels sleepy but still takes care of her 2 pets.
# But one thing hasn’t changed: Virginia still dreams of becoming a software engineer.
